# %%
import tensorflow as tf
import os
import cv2

# %%
daily_sales = [23, 34, 4, 5, 5, 66, 6, 98]

# %%
dataset = tf.data.Dataset.from_tensor_slices(daily_sales)
list(dataset.as_numpy_iterator())
# Out:
# [23, 34, 4, 5, 5, 66, 6, 98]

# %%
for u in dataset.as_numpy_iterator():
    print(type(u))
# Out:
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>

# %%
filtered = dataset.filter(lambda x: x> 23)
for u in filtered.as_numpy_iterator():
    print(u)
# Out:
# 34
# 66
# 98

# %%
filtered_mapsed = filtered.map(lambda x: x * 2)
for u in filtered_mapsed.as_numpy_iterator():
    print(u)
# Out:
# 68
# 132
# 196

# %%
for u in dataset.batch(2).as_numpy_iterator():
       print(type(u))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
dataset = tf.data.Dataset.from_tensor_slices(daily_sales)
dataset = dataset.filter(lambda x: x> 23).map(lambda x: x * 2).shuffle(2).batch(2)
for u in dataset.as_numpy_iterator():
    print(u)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x0000018CD26F6FC0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x0000018CD26F6FC0>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names. The matching definitions were:
# Match 0:
# lambda x: x * 2
#
# Match 1:
# lambda x: x > 23
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x0000018CD26F6FC0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x0000018CD26F6FC0>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names. The matching definitions were:
# Match 0:
# lambda x: x * 2
#
# Match 1:
# lambda x: x > 23
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x0000018CD2764900> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x0000018CD2764900>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names. The matching definitions were:
# Match 0:
# lambda x: x * 2
#
# Match 1:
# lambda x: x > 23
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x0000018CD2764900> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x0000018CD2764900>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names. The matching definitions were:
# Match 0:
# lambda x: x * 2
#
# Match 1:
# lambda x: x > 23
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [ 68 132]
# [196]

# %%
images_data_set = tf.data.Dataset.list_files("data/*/*", shuffle=True)
        
images_data_set
# Out:
# <_ShuffleDataset element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>

# %%
image_exts = ['jpeg','jpg', 'bmp', 'png']

# %%
data_dir = 'data'

# %%
data_images = tf.keras.utils.image_dataset_from_directory(data_dir)
# Out:
# Found 371 files belonging to 4 classes.

# %%
batch = data_images.as_numpy_iterator().next()
len(batch)
data_images.class_names
# batch[0].shape
# batch [1]
# Out:
# ['Angry', 'Other', 'Sad', 'happy']

# %%
data_images= data_images.map(lambda x, y : (x/255, tf.one_hot(y, depth = 4)))
data_images
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>

# %%
train_size = int(len(data_images)*0.7)
val_size = int(len(data_images)*0.3)
train_size + val_size
# Out:
# 11

# %%
training_ds = data_images.take(train_size)
val_ds = data_images.skip(train_size).take(val_size)
# testing_ds = data_images.skip(train_size+val_size).take(test_size)
data_images.as_numpy_iterator().next()[1].shape
# Out:
# (32, 4)

# %%
training_ds
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>

# %%
batch[1].shape
# Out:
# (32,)

# %%
batch[0].shape
# Out:
# (32, 256, 256, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, Reshape,BatchNormalization

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(4, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 3697396 (14.10 MB)
# Trainable params: 3697396 (14.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(training_ds, epochs=32, validation_data=val_ds, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/32
# 8/8 [==============================] - 13s 1s/step - loss: 0.6940 - accuracy: 0.3203 - val_loss: 0.5760 - val_accuracy: 0.3854
# Epoch 2/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.5605 - accuracy: 0.4023 - val_loss: 0.5606 - val_accuracy: 0.3229
# Epoch 3/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.5379 - accuracy: 0.4102 - val_loss: 0.5383 - val_accuracy: 0.3542
# Epoch 4/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.5374 - accuracy: 0.4180 - val_loss: 0.4865 - val_accuracy: 0.4792
# Epoch 5/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.5338 - accuracy: 0.4141 - val_loss: 0.5056 - val_accuracy: 0.5417
# Epoch 6/32
# 8/8 [==============================] - 14s 1s/step - loss: 0.5114 - accuracy: 0.4844 - val_loss: 0.4968 - val_accuracy: 0.5312
# Epoch 7/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.4915 - accuracy: 0.5664 - val_loss: 0.4882 - val_accuracy: 0.5208
# Epoch 8/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.4729 - accuracy: 0.5703 - val_loss: 0.4516 - val_accuracy: 0.5833
# Epoch 9/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.4262 - accuracy: 0.5664 - val_loss: 0.4011 - val_accuracy: 0.5833
# Epoch 10/32
# 8/8 [==============================] - 13s 1s/step - loss: 0.3874 - accuracy: 0.6641 - val_loss: 0.4094 - val_accuracy: 0.6250
# Epoch 11/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.3771 - accuracy: 0.6914 - val_loss: 0.3236 - val_accuracy: 0.8333
# Epoch 12/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.3012 - accuracy: 0.7969 - val_loss: 0.2477 - val_accuracy: 0.8125
# Epoch 13/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.2459 - accuracy: 0.8398 - val_loss: 0.2274 - val_accuracy: 0.8854
# Epoch 14/32
# 8/8 [==============================] - 13s 1s/step - loss: 0.2142 - accuracy: 0.8789 - val_loss: 0.1854 - val_accuracy: 0.8542
# Epoch 15/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.1405 - accuracy: 0.9062 - val_loss: 0.1525 - val_accuracy: 0.8750
# Epoch 16/32
# 8/8 [==============================] - 14s 2s/step - loss: 0.1113 - accuracy: 0.9453 - val_loss: 0.0802 - val_accuracy: 1.0000
# Epoch 17/32
# 8/8 [==============================] - 17s 2s/step - loss: 0.0775 - accuracy: 0.9766 - val_loss: 0.0643 - val_accuracy: 0.9583
# Epoch 18/32
# 8/8 [==============================] - 16s 2s/step - loss: 0.0573 - accuracy: 0.9727 - val_loss: 0.0455 - val_accuracy: 0.9896
# Epoch 19/32
# 8/8 [==============================] - 16s 2s/step - loss: 0.0349 - accuracy: 0.9922 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 20/32
# 8/8 [==============================] - 14s 1s/step - loss: 0.0248 - accuracy: 0.9922 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 21/32
# 8/8 [==============================] - 13s 1s/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 22/32
# 8/8 [==============================] - 15s 2s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 23/32
# 8/8 [==============================] - 13s 1s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 24/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 25/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 26/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 27/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 9.6059e-04 - val_accuracy: 1.0000
# Epoch 28/32
# 8/8 [==============================] - 12s 1s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 29/32
# 8/8 [==============================] - 17s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 30/32
# 8/8 [==============================] - 14s 1s/step - loss: 9.3138e-04 - accuracy: 1.0000 - val_loss: 6.7875e-04 - val_accuracy: 1.0000
# Epoch 31/32
# 8/8 [==============================] - 12s 1s/step - loss: 7.4755e-04 - accuracy: 1.0000 - val_loss: 8.1509e-04 - val_accuracy: 1.0000
# Epoch 32/32
# 8/8 [==============================] - 13s 1s/step - loss: 7.2631e-04 - accuracy: 1.0000 - val_loss: 5.9216e-04 - val_accuracy: 1.0000

# %%
from matplotlib import pyplot as plt
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in val_ds.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 220ms/step

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32)

# %%
import numpy as np
from keras.preprocessing import image
# Input image
test_image = image.load_img(
    f'test_images/test_image_3.jpg', target_size=(256, 256))

# For show image
plt.imshow(test_image)
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = model.predict(test_image)
result[0]
# Out:
# 1/1 [==============================] - 0s 36ms/step
# array([0., 1., 0., 0.], dtype=float32)

# %%
cat_names = ['Angry', 'happy', 'Other', 'Sad']
score = tf.nn.softmax(result[0])
print(list(cat_names)[np.argmax(score)])

percent_of_confidence = None
for u in range(len(cat_names)):
    for k in range(len(result[0])):
        if (cat_names[u] == list(cat_names)[np.argmax(score)]):
            percent_of_confidence =result[0][u] *100

print(
    f"This image most likely belongs to {list(cat_names)[np.argmax(score)]} with a {percent_of_confidence} percent confidence."
   
)
# Out:
# happy
# This image most likely belongs to happy with a 100.0 percent confidence.
